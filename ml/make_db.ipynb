# %%
import json
import os
import pandas as pd
import numpy as np
from scipy.signal import iirnotch, butter, filtfilt
from mne.preprocessing import ICA, create_eog_epochs, create_ecg_epochs
from mne.time_frequency import tfr_array_morlet
import mne
from library import *


TOLERANCE = float('2.0')

def load_one():
    data = {'_eeg': [], '_ppg': [], '_telem': [], '_events': [], '_trialData': [], '_pids':[]}
    x = json.load(open(ONE_FILE))
    for key in x.keys():
        data[key].append(x[key])
    data['_pids'].append(ONE_FILE.split('_')[0])
    return data

def load_pfiles():
    data = {'_eeg': [], '_ppg': [], '_telem': [], '_events': [], '_trialData': [], '_pids':[]}
    files = [os.path.join(DATADIR, f) for f in os.listdir(DATADIR) if os.path.isfile(os.path.join(DATADIR, f))]
    
    for f in files:
    
        x = json.load(open(f))
        for key in x.keys():
            data[key].append(x[key])
        
        pid = f.split('/')[-1].split('_')[0]
        if pid[0] == '0':
            pid = '1' + pid[1:]
            
        data['_pids'].append(pid)
    
    return data


def create_ppg_df(eeg_data):
    # data is currently in a list of each of the items in long format; put them into a single dataframe.
    PPGRAW = { 'ppgChannel':[], 'index': [], 'samples':[], 'timestamp':[] }
    for reading in eeg_data:
        for key, value in reading.items():
            PPGRAW[key].append(value)
    
    if len(PPGRAW['index']) == 0:
        raise Exception('No EEG data found in this file')

    return pd.DataFrame.from_dict(PPGRAW)

def create_eeg_df(eeg_data):
    # data is currently in a list of each of the items in long format; put them into a single dataframe.
    EEGRAW = { 'electrode':[], 'index': [], 'samples':[], 'timestamp':[] }
    for reading in eeg_data:
        for key, value in reading.items():
            EEGRAW[key].append(value)
    
    if len(EEGRAW['index']) == 0:
        raise Exception('No EEG data found in this file')

    return pd.DataFrame.from_dict(EEGRAW)

def create_event_df(event_data):
    eventDF = { 'value':[], 'timestamp':[] }
    for e in event_data:
        if 'value' in e and 'timestamp' in e and not 'mouseover' in e['value'] and not 'mouseout' in e['value']:
            eventDF['value'].append(e['value'])
            eventDF['timestamp'].append(e['timestamp'])

    eventDF = pd.DataFrame.from_dict(eventDF)
    eventDF['timestamp'] = eventDF['timestamp'].astype(float)

    if len(eventDF) == 0:
        raise Exception('No events found in this file')

    return eventDF



def widen_ppg_data(PPG_LONG, EEG_LONG):    
    PPG_SAMPLING_RATE = 64    
    start_time = EEG_LONG.loc[0, 'timestamp'] # let's assume eeg and ppg start at the same time.
    reading_offset = 1000 / SAMPLING_RATE
    n_samples = 6 
    n_probes = 3

    pivoted_df = PPG_LONG.pivot(index='index', columns='ppgChannel', values='samples')
    pivoted_df.columns = [f'ppgChan-{col}' for col in pivoted_df.columns]    
    wide_df = pivoted_df.apply(lambda x: x.explode()).reset_index().drop(columns=['index'])

    # add the timestamp; data is coming in at 64 h
    wide_df['timestamp'] = [start_time + reading_offset * i for i in range(len(wide_df))]
    return wide_df

def widen_eeg_data(EEG_LONG):    
    # We know the data is coming in at 256hz. 
    start_time = EEG_LONG.loc[0,'timestamp']
    reading_offset = 1000 / SAMPLING_RATE
    n_samples = 12 
    n_probes = 4

    pivoted_df = EEG_LONG.pivot(index='index', columns='electrode', values='samples')
    pivoted_df.columns = [f'probe-{col}' for col in pivoted_df.columns]
    # print(pivoted_df[pivoted_df.index.duplicated()])
    # print(pivoted_df)
    wide_df = pivoted_df.apply(lambda x: x.explode()).reset_index().drop(columns=['index'])
    print(wide_df)
    
    # add the timestamp; data is coming in at 256hz.
    wide_df['timestamp'] = [start_time + reading_offset * i for i in range(len(wide_df))]
    return wide_df

def merge_dfs(EEG_WIDE, EVENT_DF, tolerance=TOLERANCE):
    
    # merge the events with the data
    df = pd.merge_asof(EEG_WIDE, EVENT_DF, on="timestamp", direction="nearest", tolerance=tolerance)
    
    # only keep the first encountered marker of each type. with 2ms tolerance that should be close enough. 
    df['value'] = df['value'].drop_duplicates()
    df['value'] = df['value'].astype(str)

    # ground truth how many puzzle solved events -- background info in case the merge has too low of a tolerance
    events_gt = sum([1 for e in EVENT_DF['value'].unique() if 'puzzle_finished' in e or 'puzzle_loaded' in e])
    events_eeg = sum([1 for e in df['value'] if 'puzzle_finished' in e or 'puzzle_loaded' in e])
    print(f'Found {events_gt} start/stop events, {events_eeg} start/stop eeg events [THESE SHOULD BE THE SAME]')
    if events_gt != events_eeg:
        print(EVENT_DF['value'].unique())
        raise Exception(f'Mismatch in number of start/stop events: {events_gt} vs {events_eeg}')

    return df


DATA = load_one() if ONE_FILE else load_pfiles()

num_files = len(DATA['_eeg'])

n_passed = 0
n_failed = 0
MERGED_DFS = []
for i in range(num_files):
    print(i)
    try:   
        
        EVENT_DF = create_event_df(DATA['_events'][i])
        
        EEG_LONG = create_eeg_df(DATA['_eeg'][i])    
        #PPG_LONG = create_ppg_df(DATA['_ppg'][i])
        
        #PPG_WIDE = widen_ppg_data(PPG_LONG, EEG_LONG)        
        EEG_WIDE = widen_eeg_data(EEG_LONG) 
        MERGED_DF = merge_dfs(EEG_WIDE, EVENT_DF) 
        #MERGED_DF = merge_dfs(PPG_WIDE, EVENT_DF, tolerance=TOLERANCE*100)

    except Exception as e:
        print(e)
        n_failed += 1
        continue
   
    MERGED_DF['pid'] = DATA['_pids'][i]
    print(MERGED_DF)

    MERGED_DFS.append(MERGED_DF)
    n_passed += 1

MERGED_DF = pd.concat(MERGED_DFS)
MERGED_DF.to_csv(DBFNAME, index=False)
# Out:
# 0
#           probe-0     probe-1     probe-2    probe-3
# 0       -0.488281           0   -0.488281          0
# 1               0   -2.441406    1.464844  -0.488281
# 2        1.464844    7.324219    19.53125          0
# 3        -3.90625  -27.832031  -94.238281   0.976562
# 4       20.996094   49.804688  443.359375   0.976562
# ...           ...         ...         ...        ...
# 116923 -26.367188 -518.066406      -312.5 -42.480469
# 116924 -30.273438   94.726562  -38.574219 -17.578125
# 116925 -28.320312  290.527344   57.617188   -3.90625
# 116926 -27.832031 -112.304688 -168.945312 -25.390625
# 116927 -38.085938  -11.230469  -80.566406 -54.199219
#
# [116928 rows x 4 columns]
# Found 60 start/stop events, 60 start/stop eeg events [THESE SHOULD BE THE SAME]
#           probe-0     probe-1     probe-2    probe-3     timestamp value  \
# 0       -0.488281           0   -0.488281          0  1.683055e+12   nan
# 1               0   -2.441406    1.464844  -0.488281  1.683055e+12   nan
# 2        1.464844    7.324219    19.53125          0  1.683055e+12   nan
# 3        -3.90625  -27.832031  -94.238281   0.976562  1.683055e+12   nan
# 4       20.996094   49.804688  443.359375   0.976562  1.683055e+12   nan
# ...           ...         ...         ...        ...           ...   ...
# 116923 -26.367188 -518.066406      -312.5 -42.480469  1.683055e+12   nan
# 116924 -30.273438   94.726562  -38.574219 -17.578125  1.683055e+12   nan
# 116925 -28.320312  290.527344   57.617188   -3.90625  1.683055e+12   nan
# 116926 -27.832031 -112.304688 -168.945312 -25.390625  1.683055e+12   nan
# 116927 -38.085938  -11.230469  -80.566406 -54.199219  1.683055e+12   nan
#
#              pid
# 0       2a7ba24a
# 1       2a7ba24a
# 2       2a7ba24a
# 3       2a7ba24a
# 4       2a7ba24a
# ...          ...
# 116923  2a7ba24a
# 116924  2a7ba24a
# 116925  2a7ba24a
# 116926  2a7ba24a
# 116927  2a7ba24a
#
# [116928 rows x 7 columns]
# 1
#          probe-0    probe-1    probe-2    probe-3
# 0              0          0          0          0
# 1              0          0  -0.488281  -0.488281
# 2      -1.464844  -1.464844  -0.488281  -1.953125
# 3       2.929688   1.953125  -0.976562   4.394531
# 4     -16.113281 -12.207031  -1.464844   -23.4375
# ...          ...        ...        ...        ...
# 96487 -31.738281 -33.691406 -33.691406 -31.738281
# 96488 -34.667969   -39.0625     -31.25 -34.179688
# 96489 -31.738281 -38.085938 -28.320312 -21.972656
# 96490 -33.203125 -29.785156 -36.132812 -26.855469
# 96491 -33.203125 -28.808594 -29.296875  -35.15625
#
# [96492 rows x 4 columns]
# Found 60 start/stop events, 60 start/stop eeg events [THESE SHOULD BE THE SAME]
#          probe-0    probe-1    probe-2    probe-3     timestamp value  \
# 0              0          0          0          0  1.682541e+12   nan
# 1              0          0  -0.488281  -0.488281  1.682541e+12   nan
# 2      -1.464844  -1.464844  -0.488281  -1.953125  1.682541e+12   nan
# 3       2.929688   1.953125  -0.976562   4.394531  1.682541e+12   nan
# 4     -16.113281 -12.207031  -1.464844   -23.4375  1.682541e+12   nan
# ...          ...        ...        ...        ...           ...   ...
# 96487 -31.738281 -33.691406 -33.691406 -31.738281  1.682542e+12   nan
# 96488 -34.667969   -39.0625     -31.25 -34.179688  1.682542e+12   nan
# 96489 -31.738281 -38.085938 -28.320312 -21.972656  1.682542e+12   nan
# 96490 -33.203125 -29.785156 -36.132812 -26.855469  1.682542e+12   nan
# 96491 -33.203125 -28.808594 -29.296875  -35.15625  1.682542e+12   nan
#
#             pid
# 0      44dd5d31
# 1      44dd5d31
# 2      44dd5d31
# 3      44dd5d31
# 4      44dd5d31
# ...         ...
# 96487  44dd5d31
# 96488  44dd5d31
# 96489  44dd5d31
# 96490  44dd5d31
# 96491  44dd5d31
#
# [96492 rows x 7 columns]
# 2
#          probe-0    probe-1    probe-2    probe-3
# 0              0          0          0          0
# 1              0          0  -0.488281  -0.488281
# 2      -2.929688  -3.417969  -0.976562  -0.976562
# 3       4.882812   6.835938   0.976562   1.953125
# 4     -24.414062 -40.039062 -14.160156 -12.695312
# ...          ...        ...        ...        ...
# 82051  18.066406 -54.199219 -47.363281  14.160156
# 82052  31.738281 -54.199219 -42.480469  25.878906
# 82053  26.367188 -51.269531 -39.550781  30.761719
# 82054  14.160156 -46.386719 -41.015625  25.390625
# 82055   19.53125 -51.757812 -38.085938  29.785156
#
# [82056 rows x 4 columns]
# Found 60 start/stop events, 60 start/stop eeg events [THESE SHOULD BE THE SAME]
#          probe-0    probe-1    probe-2    probe-3     timestamp value  \
# 0              0          0          0          0  1.683213e+12   nan
# 1              0          0  -0.488281  -0.488281  1.683213e+12   nan
# 2      -2.929688  -3.417969  -0.976562  -0.976562  1.683213e+12   nan
# 3       4.882812   6.835938   0.976562   1.953125  1.683213e+12   nan
# 4     -24.414062 -40.039062 -14.160156 -12.695312  1.683213e+12   nan
# ...          ...        ...        ...        ...           ...   ...
# 82051  18.066406 -54.199219 -47.363281  14.160156  1.683213e+12   nan
# 82052  31.738281 -54.199219 -42.480469  25.878906  1.683213e+12   nan
# 82053  26.367188 -51.269531 -39.550781  30.761719  1.683213e+12   nan
# 82054  14.160156 -46.386719 -41.015625  25.390625  1.683213e+12   nan
# 82055   19.53125 -51.757812 -38.085938  29.785156  1.683213e+12   nan
#
#             pid
# 0      92511e53
# 1      92511e53
# 2      92511e53
# 3      92511e53
# 4      92511e53
# ...         ...
# 82051  92511e53
# 82052  92511e53
# 82053  92511e53
# 82054  92511e53
# 82055  92511e53
#
# [82056 rows x 7 columns]
# 3
#          probe-0    probe-1    probe-2    probe-3
# 0              0          0          0          0
# 1              0  -0.488281  -0.488281          0
# 2      -1.953125  -0.976562  -1.464844  -1.464844
# 3       2.929688   1.464844   1.464844   2.929688
# 4     -16.601562 -10.742188 -13.183594    -15.625
# ...          ...        ...        ...        ...
# 29755 -29.785156 -34.179688 -29.785156 -25.878906
# 29756 -22.460938 -32.714844 -30.273438 -18.554688
# 29757 -18.066406 -31.738281 -31.738281 -17.578125
# 29758 -25.390625 -31.738281 -30.273438 -26.855469
# 29759 -37.597656 -36.621094 -33.203125 -35.644531
#
# [29760 rows x 4 columns]
# Found 80 start/stop events, 31 start/stop eeg events [THESE SHOULD BE THE SAME]
# ['STATUS: block_started; BLOCK: 0' 'STATUS: rest_loaded'
#  'STATUS: rest_ended'
#  'STATUS: puzzle_loaded; ELO: 800; PUZZLESTR: DRoAA,r5k1/p4Qpp/8/8/1P6/P1q4b/2P2RP1/6K1 b - - 0 25,g8h8 f7f8 a8f8 f2f8,800,88,83,41,backRankMate endgame mate mateIn2 sacrifice short,https://lichess.org/SZ9mwGbP/black#50,'
#  'STATUS: opponent_moved; FEN: r6k/p4Qpp/8/8/1P6/P1q4b/2P2RP1/6K1 w - - 1 26'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f7; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: f7; TARGET: f8; MOVE_NUM: 1; FEN: r4Q1k/p5pp/8/8/1P6/P1q4b/2P2RP1/6K1 b - - 2 26; ELO: 800'
#  'STATUS: opponent_moved; FEN: 5r1k/p5pp/8/8/1P6/P1q4b/2P2RP1/6K1 w - - 0 27'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: f2; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f2; TARGET: f8; MOVE_NUM: 3; FEN: 5R1k/p5pp/8/8/1P6/P1q4b/2P3P1/6K1 b - - 0 27; ELO: 800'
#  'STATUS: trial_ended; TRIAL: 0'
#  'STATUS: puzzle_loaded; ELO: 850; PUZZLESTR: Uf7mr,6rk/8/r7/p4N1p/1ppP1Nn1/7K/PPBB3P/4R3 w - - 4 37,f4h5 g4f2 h3h4 g8g4,883,87,92,165,mate mateIn2 middlegame short,https://lichess.org/ja0AQzj3#73,'
#  'STATUS: opponent_moved; FEN: 6rk/8/r7/p4N1N/1ppP2n1/7K/PPBB3P/4R3 b - - 0 37'
#  'STATUS: piece_drag_start; PIECE: bN; SOURCE: g4; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: g4; TARGET: f2; MOVE_NUM: 1; FEN: 6rk/8/r7/p4N1N/1ppP4/7K/PPBB1n1P/4R3 w - - 1 38; ELO: 850'
#  'STATUS: opponent_moved; FEN: 6rk/8/r7/p4N1N/1ppP3K/8/PPBB1n1P/4R3 b - - 2 38'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: g8; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g8; TARGET: g4; MOVE_NUM: 3; FEN: 7k/8/r7/p4N1N/1ppP2rK/8/PPBB1n1P/4R3 w - - 3 39; ELO: 850'
#  'STATUS: trial_ended; TRIAL: 1'
#  'STATUS: puzzle_loaded; ELO: 900; PUZZLESTR: 5L2Ui,1k1Q2nr/ppp1b2p/5p2/5BP1/2N2p2/5q2/PPP5/2KR3R b - - 2 20,e7d8 d1d8,946,87,67,41,backRankMate mate mateIn1 middlegame oneMove,https://lichess.org/0VtCE4bc/black#40,'
#  'STATUS: opponent_moved; FEN: 1k1b2nr/ppp4p/5p2/5BP1/2N2p2/5q2/PPP5/2KR3R w - - 0 21'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: d1; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d1; TARGET: d8; MOVE_NUM: 1; FEN: 1k1R2nr/ppp4p/5p2/5BP1/2N2p2/5q2/PPP5/2K4R b - - 0 21; ELO: 900'
#  'STATUS: trial_ended; TRIAL: 2'
#  'STATUS: puzzle_loaded; ELO: 950; PUZZLESTR: sGCEZ,r4rk1/p5P1/4p1P1/1q2PpB1/2p5/2p3Q1/P1P5/1K1R3R w - - 1 29,b1c1 b5b2,966,79,89,82,mate mateIn1 middlegame oneMove,https://lichess.org/q9deI1Si#57,'
#  'STATUS: opponent_moved; FEN: r4rk1/p5P1/4p1P1/1q2PpB1/2p5/2p3Q1/P1P5/2KR3R b - - 2 29'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: b5; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: b5; TARGET: b2; MOVE_NUM: 1; FEN: r4rk1/p5P1/4p1P1/4PpB1/2p5/2p3Q1/PqP5/2KR3R w - - 3 30; ELO: 950'
#  'STATUS: trial_ended; TRIAL: 3'
#  'STATUS: puzzle_loaded; ELO: 1000; PUZZLESTR: ne5px,r5Rr/p1qkb2B/3p4/3P1Q2/2Pp1p2/7b/P2P1P2/R1B1K3 b Q - 6 22,h3f5 h7f5,1032,85,100,103,mate mateIn1 middlegame oneMove,https://lichess.org/ESgrvhgH/black#44,'
#  'STATUS: opponent_moved; FEN: r5Rr/p1qkb2B/3p4/3P1b2/2Pp1p2/8/P2P1P2/R1B1K3 w Q - 0 23'
#  'STATUS: piece_drag_start; PIECE: wB; SOURCE: h7; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: h7; TARGET: f5; MOVE_NUM: 1; FEN: r5Rr/p1qkb3/3p4/3P1B2/2Pp1p2/8/P2P1P2/R1B1K3 b Q - 0 23; ELO: 1000'
#  'STATUS: trial_ended; TRIAL: 4'
#  'STATUS: puzzle_loaded; ELO: 1050; PUZZLESTR: Vjtb5,r1b3k1/p4qpp/2N5/1p6/3bP3/PQ5P/1P4P1/5R1K b - - 1 21,f7b3 c6e7 g8h8 f1f8 b3g8 f8g8,1086,159,100,23,endgame long mate mateIn3,https://lichess.org/t8LCrrbG/black#42,'
#  'STATUS: opponent_moved; FEN: r1b3k1/p5pp/2N5/1p6/3bP3/Pq5P/1P4P1/5R1K w - - 0 22'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: c6; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: c6; TARGET: e7; MOVE_NUM: 1; FEN: r1b3k1/p3N1pp/8/1p6/3bP3/Pq5P/1P4P1/5R1K b - - 1 22; ELO: 1050'
#  'STATUS: opponent_moved; FEN: r1b4k/p3N1pp/8/1p6/3bP3/Pq5P/1P4P1/5R1K w - - 2 23'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: f1; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: f1; TARGET: f8; MOVE_NUM: 3; FEN: r1b2R1k/p3N1pp/8/1p6/3bP3/Pq5P/1P4P1/7K b - - 3 23; ELO: 1050'
#  'STATUS: opponent_moved; FEN: r1b2Rqk/p3N1pp/8/1p6/3bP3/P6P/1P4P1/7K w - - 4 24'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: f8; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f8; TARGET: g8; MOVE_NUM: 5; FEN: r1b3Rk/p3N1pp/8/1p6/3bP3/P6P/1P4P1/7K b - - 0 24; ELO: 1050'
#  'STATUS: trial_ended; TRIAL: 5'
#  'STATUS: puzzle_loaded; ELO: 1100; PUZZLESTR: mn1yx,5rk1/3P1ppp/4p3/2Qp4/1p2q3/6P1/5P1P/6K1 b - - 5 36,e4c4 c5f8 g8f8 d7d8q,1146,75,92,1188,advancedPawn attraction endgame mate mateIn2 promotion short,https://lichess.org/RIkciNQI/black#72,'
#  'STATUS: opponent_moved; FEN: 5rk1/3P1ppp/4p3/2Qp4/1pq5/6P1/5P1P/6K1 w - - 6 37'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: c5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: c5; TARGET: f8; MOVE_NUM: 1; FEN: 5Qk1/3P1ppp/4p3/3p4/1pq5/6P1/5P1P/6K1 b - - 0 37; ELO: 1100'
#  'STATUS: opponent_moved; FEN: 5k2/3P1ppp/4p3/3p4/1pq5/6P1/5P1P/6K1 w - - 0 38'
#  'STATUS: piece_drag_start; PIECE: wP; SOURCE: d7; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d7; TARGET: d8; MOVE_NUM: 3; FEN: 3Q1k2/5ppp/4p3/3p4/1pq5/6P1/5P1P/6K1 b - - 0 38; ELO: 1100'
#  'STATUS: trial_ended; TRIAL: 6'
#  'STATUS: puzzle_loaded; ELO: 1150; PUZZLESTR: DQgQW,rn4k1/p4ppp/2p3b1/1pB1N3/6P1/2PB2nq/PP1K1Q2/R7 b - - 0 23,g6d3 f2f7 g8h8 f7e8,1155,80,91,408,backRankMate mate mateIn2 middlegame short,https://lichess.org/hbxJgz1B/black#46,'
#  'STATUS: opponent_moved; FEN: rn4k1/p4ppp/2p5/1pB1N3/6P1/2Pb2nq/PP1K1Q2/R7 w - - 0 24'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f2; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: f2; TARGET: f7; MOVE_NUM: 1; FEN: rn4k1/p4Qpp/2p5/1pB1N3/6P1/2Pb2nq/PP1K4/R7 b - - 0 24; ELO: 1150'
#  'STATUS: opponent_moved; FEN: rn5k/p4Qpp/2p5/1pB1N3/6P1/2Pb2nq/PP1K4/R7 w - - 1 25'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f7; TARGET: f8; MOVE_NUM: 3; FEN: rn3Q1k/p5pp/2p5/1pB1N3/6P1/2Pb2nq/PP1K4/R7 b - - 2 25; ELO: 1150'
#  'STATUS: trial_ended; TRIAL: 7'
#  'STATUS: puzzle_loaded; ELO: 1200; PUZZLESTR: S2kop,r6k/8/p2p2p1/2p1pbN1/2pq4/5P2/PP5Q/2K3R1 b - - 1 30,h8g7 h2h7 g7f6 h7f7,1240,78,82,105,endgame mate mateIn2 short,https://lichess.org/vbHB0ime/black#60,'
#  'STATUS: opponent_moved; FEN: r7/6k1/p2p2p1/2p1pbN1/2pq4/5P2/PP5Q/2K3R1 w - - 2 31'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h2; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: h2; TARGET: h7; MOVE_NUM: 1; FEN: r7/6kQ/p2p2p1/2p1pbN1/2pq4/5P2/PP6/2K3R1 b - - 3 31; ELO: 1200'
#  'STATUS: opponent_moved; FEN: r7/7Q/p2p1kp1/2p1pbN1/2pq4/5P2/PP6/2K3R1 w - - 4 32'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h7; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: h7; TARGET: f7; MOVE_NUM: 3; FEN: r7/5Q2/p2p1kp1/2p1pbN1/2pq4/5P2/PP6/2K3R1 b - - 5 32; ELO: 1200'
#  'STATUS: trial_ended; TRIAL: 8'
#  'STATUS: puzzle_loaded; ELO: 1250; PUZZLESTR: JEGXY,r1br2k1/pp3ppp/4p3/8/1b2Q3/2q3P1/PPP4P/R1K2B1R w - - 0 18,b2c3 b4a3 c1b1 d8d1,1257,139,71,15,mate mateIn2 middlegame queensideAttack short,https://lichess.org/wfwVybTx#35,Sicilian_Defense,Sicilian_Defense_Four_Knights_Variation'
#  'STATUS: opponent_moved; FEN: r1br2k1/pp3ppp/4p3/8/1b2Q3/2P3P1/P1P4P/R1K2B1R b - - 0 18'
#  'STATUS: piece_drag_start; PIECE: bB; SOURCE: b4; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: b4; TARGET: a3; MOVE_NUM: 1; FEN: r1br2k1/pp3ppp/4p3/8/4Q3/b1P3P1/P1P4P/R1K2B1R w - - 1 19; ELO: 1250'
#  'STATUS: opponent_moved; FEN: r1br2k1/pp3ppp/4p3/8/4Q3/b1P3P1/P1P4P/RK3B1R b - - 2 19'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: d8; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d8; TARGET: d1; MOVE_NUM: 3; FEN: r1b3k1/pp3ppp/4p3/8/4Q3/b1P3P1/P1P4P/RK1r1B1R w - - 3 20; ELO: 1250'
#  'STATUS: trial_ended; TRIAL: 9'
#  'STATUS: puzzle_loaded; ELO: 1300; PUZZLESTR: BKiFp,r5k1/pQ3ppp/2p5/4r1q1/2PpP1b1/3K1RP1/PP5P/R7 b - - 0 24,a8e8 b7f7 g8h8 f7f8 e8f8 f3f8,1312,77,80,220,backRankMate long mate mateIn3 middlegame sacrifice,https://lichess.org/Q7UEKoQW/black#48,'
#  'STATUS: opponent_moved; FEN: 4r1k1/pQ3ppp/2p5/4r1q1/2PpP1b1/3K1RP1/PP5P/R7 w - - 1 25'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: b7; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: b7; TARGET: f7; MOVE_NUM: 1; FEN: 4r1k1/p4Qpp/2p5/4r1q1/2PpP1b1/3K1RP1/PP5P/R7 b - - 0 25; ELO: 1300'
#  'STATUS: opponent_moved; FEN: 4r2k/p4Qpp/2p5/4r1q1/2PpP1b1/3K1RP1/PP5P/R7 w - - 1 26'
#  'STATUS: correct_move; RESULT: move; SOURCE: f7; TARGET: f8; MOVE_NUM: 3; FEN: 4rQ1k/p5pp/2p5/4r1q1/2PpP1b1/3K1RP1/PP5P/R7 b - - 2 26; ELO: 1300'
#  'STATUS: opponent_moved; FEN: 5r1k/p5pp/2p5/4r1q1/2PpP1b1/3K1RP1/PP5P/R7 w - - 0 27'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: f3; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f3; TARGET: f8; MOVE_NUM: 5; FEN: 5R1k/p5pp/2p5/4r1q1/2PpP1b1/3K2P1/PP5P/R7 b - - 0 27; ELO: 1300'
#  'STATUS: trial_ended; TRIAL: 10'
#  'STATUS: puzzle_loaded; ELO: 1350; PUZZLESTR: YsMRt,8/3R3p/4Q1pk/4Pp2/1q3P2/2p4P/6PK/r7 w - - 3 35,e6g8 b4f4 g2g3 f4f2,1354,107,56,13,endgame mate mateIn2 short,https://lichess.org/Jz2yBqT4#69,'
#  'STATUS: opponent_moved; FEN: 6Q1/3R3p/6pk/4Pp2/1q3P2/2p4P/6PK/r7 b - - 4 35'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: b4; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: b4; TARGET: f4; MOVE_NUM: 1; FEN: 6Q1/3R3p/6pk/4Pp2/5q2/2p4P/6PK/r7 w - - 0 36; ELO: 1350'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: f4; ORIENTATION: black; INFO: wrong_side'
#  'STATUS: opponent_moved; FEN: 6Q1/3R3p/6pk/4Pp2/5q2/2p3PP/7K/r7 b - - 0 36'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: f4; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f4; TARGET: f2; MOVE_NUM: 3; FEN: 6Q1/3R3p/6pk/4Pp2/8/2p3PP/5q1K/r7 w - - 1 37; ELO: 1350'
#  'STATUS: trial_ended; TRIAL: 11'
#  'STATUS: puzzle_loaded; ELO: 1400; PUZZLESTR: Ggc7M,r3q1r1/1pp2p1k/p2b1B1p/5P1Q/5nP1/1P5P/1PP2P2/R3R1K1 b - - 2 24,e8c6 h5f7 g8g7 f7g7,1405,81,86,93,mate mateIn2 middlegame short,https://lichess.org/Rm922cC3/black#48,'
#  'STATUS: opponent_moved; FEN: r5r1/1pp2p1k/p1qb1B1p/5P1Q/5nP1/1P5P/1PP2P2/R3R1K1 w - - 3 25'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: h5; TARGET: f7; MOVE_NUM: 1; FEN: r5r1/1pp2Q1k/p1qb1B1p/5P2/5nP1/1P5P/1PP2P2/R3R1K1 b - - 0 25; ELO: 1400'
#  'STATUS: opponent_moved; FEN: r7/1pp2Qrk/p1qb1B1p/5P2/5nP1/1P5P/1PP2P2/R3R1K1 w - - 1 26'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f7; TARGET: g7; MOVE_NUM: 3; FEN: r7/1pp3Qk/p1qb1B1p/5P2/5nP1/1P5P/1PP2P2/R3R1K1 b - - 0 26; ELO: 1400'
#  'STATUS: trial_ended; TRIAL: 12'
#  'STATUS: puzzle_loaded; ELO: 1450; PUZZLESTR: 2qKu4,1k3r1r/np6/p2Np3/4PB2/1P1P4/5Q2/R4KNq/8 b - - 10 41,e6f5 f3b7,1469,246,55,51,mate mateIn1 middlegame oneMove,https://lichess.org/2YS7GmJl/black#82,'
#  'STATUS: opponent_moved; FEN: 1k3r1r/np6/p2N4/4Pp2/1P1P4/5Q2/R4KNq/8 w - - 0 42'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f3; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f3; TARGET: b7; MOVE_NUM: 1; FEN: 1k3r1r/nQ6/p2N4/4Pp2/1P1P4/8/R4KNq/8 b - - 0 42; ELO: 1450'
#  'STATUS: trial_ended; TRIAL: 13'
#  'STATUS: puzzle_loaded; ELO: 1500; PUZZLESTR: wKQrz,8/8/8/2R3k1/8/5K2/r1p3P1/8 b - - 4 55,g5h4 g2g3 h4h3 c5h5,1501,74,97,2467,endgame mate mateIn2 rookEndgame short,https://lichess.org/ZOR4hcAf/black#110,'
#  'STATUS: opponent_moved; FEN: 8/8/8/2R5/7k/5K2/r1p3P1/8 w - - 5 56'
#  'STATUS: piece_drag_start; PIECE: wP; SOURCE: g2; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: g2; TARGET: g3; MOVE_NUM: 1; FEN: 8/8/8/2R5/7k/5KP1/r1p5/8 b - - 0 56; ELO: 1500'
#  'STATUS: opponent_moved; FEN: 8/8/8/2R5/8/5KPk/r1p5/8 w - - 1 57'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: c5; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: c5; TARGET: h5; MOVE_NUM: 3; FEN: 8/8/8/7R/8/5KPk/r1p5/8 b - - 2 57; ELO: 1500'
#  'STATUS: trial_ended; TRIAL: 14'
#  'STATUS: puzzle_loaded; ELO: 1550; PUZZLESTR: oNqrm,r4r1k/pp1N1pp1/1q2p2p/3pB2Q/3P4/8/PP3bPP/R6K b - - 1 20,b6b2 h5h6 h8g8 h6g7,1569,75,100,856,kingsideAttack mate mateIn2 middlegame pin short,https://lichess.org/jySbbweB/black#40,'
#  'STATUS: opponent_moved; FEN: r4r1k/pp1N1pp1/4p2p/3pB2Q/3P4/8/Pq3bPP/R6K w - - 0 21'
#  'STATUS: correct_move; RESULT: capture; SOURCE: h5; TARGET: h6; MOVE_NUM: 1; FEN: r4r1k/pp1N1pp1/4p2Q/3pB3/3P4/8/Pq3bPP/R6K b - - 0 21; ELO: 1550'
#  'STATUS: opponent_moved; FEN: r4rk1/pp1N1pp1/4p2Q/3pB3/3P4/8/Pq3bPP/R6K w - - 1 22'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h6; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: h6; TARGET: g7; MOVE_NUM: 3; FEN: r4rk1/pp1N1pQ1/4p3/3pB3/3P4/8/Pq3bPP/R6K b - - 0 22; ELO: 1550'
#  'STATUS: trial_ended; TRIAL: 15'
#  'STATUS: puzzle_loaded; ELO: 1600; PUZZLESTR: ZLgd4,r1b2rk1/p2p1ppp/1p1Q4/4B3/4q3/2P3PP/PP3P2/4RRK1 b - - 1 19,e4f3 d6f8 g8f8 e5d6 f8g8 e1e8,1600,83,84,390,attraction backRankMate long mate mateIn3 middlegame sacrifice,https://lichess.org/tGDpCfqU/black#38,Englund_Gambit_Complex,Englund_Gambit_Complex_Englund_Gambit'
#  'STATUS: opponent_moved; FEN: r1b2rk1/p2p1ppp/1p1Q4/4B3/8/2P2qPP/PP3P2/4RRK1 w - - 2 20'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: d6; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: d6; TARGET: f8; MOVE_NUM: 1; FEN: r1b2Qk1/p2p1ppp/1p6/4B3/8/2P2qPP/PP3P2/4RRK1 b - - 0 20; ELO: 1600'
#  'STATUS: opponent_moved; FEN: r1b2k2/p2p1ppp/1p6/4B3/8/2P2qPP/PP3P2/4RRK1 w - - 0 21'
#  'STATUS: piece_drag_start; PIECE: wB; SOURCE: e5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: e5; TARGET: d6; MOVE_NUM: 3; FEN: r1b2k2/p2p1ppp/1p1B4/8/8/2P2qPP/PP3P2/4RRK1 b - - 1 21; ELO: 1600'
#  'STATUS: opponent_moved; FEN: r1b3k1/p2p1ppp/1p1B4/8/8/2P2qPP/PP3P2/4RRK1 w - - 2 22'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: e1; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e1; TARGET: e8; MOVE_NUM: 5; FEN: r1b1R1k1/p2p1ppp/1p1B4/8/8/2P2qPP/PP3P2/5RK1 b - - 3 22; ELO: 1600'
#  'STATUS: trial_ended; TRIAL: 16'
#  'STATUS: puzzle_loaded; ELO: 1650; PUZZLESTR: XdM5e,3r2k1/6b1/8/2p3pQ/4Pp2/1P5P/2P1n1P1/BK1q1R2 w - - 1 34,f1d1 d8d1 b1a2 d1a1,1662,74,97,516,endgame master mate mateIn2 short,https://lichess.org/2Ous0w8K#67,'
#  'STATUS: opponent_moved; FEN: 3r2k1/6b1/8/2p3pQ/4Pp2/1P5P/2P1n1P1/BK1R4 b - - 0 34'
#  'STATUS: correct_move; RESULT: capture; SOURCE: d8; TARGET: d1; MOVE_NUM: 1; FEN: 6k1/6b1/8/2p3pQ/4Pp2/1P5P/2P1n1P1/BK1r4 w - - 0 35; ELO: 1650'
#  'STATUS: opponent_moved; FEN: 6k1/6b1/8/2p3pQ/4Pp2/1P5P/K1P1n1P1/B2r4 b - - 1 35'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: d1; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d1; TARGET: a1; MOVE_NUM: 3; FEN: 6k1/6b1/8/2p3pQ/4Pp2/1P5P/K1P1n1P1/r7 w - - 0 36; ELO: 1650'
#  'STATUS: trial_ended; TRIAL: 17'
#  'STATUS: puzzle_loaded; ELO: 1700; PUZZLESTR: AXI8I,1b5k/2q5/4Qp1p/3p4/3N4/4P1rP/2P2P2/5RK1 w - - 0 34,g1h1 g3g1 h1g1 c7h2,1711,81,83,38,attraction endgame mate mateIn2 sacrifice short,https://lichess.org/h2kLizkA#67,'
#  'STATUS: opponent_moved; FEN: 1b5k/2q5/4Qp1p/3p4/3N4/4P1rP/2P2P2/5R1K b - - 1 34'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: g3; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: g3; TARGET: h3; MOVE_NUM: 1; FEN: 1b5k/2q5/4Qp1p/3p4/3N4/4P2r/2P2P2/5R1K w - - 0 35; ELO: 1700'
#  'STATUS: trial_ended; TRIAL: 18'
#  'STATUS: puzzle_loaded; ELO: 1650; PUZZLESTR: R1nOW,4rr2/5pkn/p3q3/4R3/2p2Q1R/2N5/PPP3P1/1K6 b - - 0 31,e6e5 f4h6 g7h8 h6h7,1681,74,90,558,mate mateIn2 middlegame short,https://lichess.org/vW3ycGAR/black#62,'
#  'STATUS: opponent_moved; FEN: 4rr2/5pkn/p7/4q3/2p2Q1R/2N5/PPP3P1/1K6 w - - 0 32'
#  'STATUS: puzzle_finished; RESULT: timeout'
#  'STATUS: trial_ended; TRIAL: 19'
#  'STATUS: puzzle_loaded; ELO: 1600; PUZZLESTR: VqMMP,r6k/ppp2Rpp/1nnb4/6P1/6P1/P1B4P/BP2r3/5RK1 b - - 6 25,a8g8 c3g7 g8g7 f7f8 d6f8 f1f8 g7g8 f8g8,1644,76,88,129,kingsideAttack mate mateIn4 middlegame sacrifice veryLong,https://lichess.org/RULOGESE/black#50,'
#  'STATUS: opponent_moved; FEN: 6rk/ppp2Rpp/1nnb4/6P1/6P1/P1B4P/BP2r3/5RK1 w - - 7 26'
#  'STATUS: piece_drag_start; PIECE: wB; SOURCE: c3; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: c3; TARGET: g7; MOVE_NUM: 1; FEN: 6rk/ppp2RBp/1nnb4/6P1/6P1/P6P/BP2r3/5RK1 b - - 0 26; ELO: 1600'
#  'STATUS: opponent_moved; FEN: 7k/ppp2Rrp/1nnb4/6P1/6P1/P6P/BP2r3/5RK1 w - - 0 27'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: f7; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: f7; TARGET: f8; MOVE_NUM: 3; FEN: 5R1k/ppp3rp/1nnb4/6P1/6P1/P6P/BP2r3/5RK1 b - - 1 27; ELO: 1600'
#  'STATUS: opponent_moved; FEN: 5b1k/ppp3rp/1nn5/6P1/6P1/P6P/BP2r3/5RK1 w - - 0 28'
#  'STATUS: correct_move; RESULT: capture; SOURCE: f1; TARGET: f8; MOVE_NUM: 5; FEN: 5R1k/ppp3rp/1nn5/6P1/6P1/P6P/BP2r3/6K1 b - - 0 28; ELO: 1600'
#  'STATUS: opponent_moved; FEN: 5Rrk/ppp4p/1nn5/6P1/6P1/P6P/BP2r3/6K1 w - - 1 29'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f8; TARGET: g8; MOVE_NUM: 7; FEN: 6Rk/ppp4p/1nn5/6P1/6P1/P6P/BP2r3/6K1 b - - 0 29; ELO: 1600'
#  'STATUS: trial_ended; TRIAL: 20'
#  'STATUS: puzzle_loaded; ELO: 1650; PUZZLESTR: IaXMy,2r3k1/p3Nppp/1pn5/6q1/2Qb1N2/6P1/PP3P1P/4R1K1 b - - 4 20,c6e7 c4c8 e7c8 e1e8,1694,75,90,2849,backRankMate mate mateIn2 middlegame sacrifice short,https://lichess.org/bYWQNTti/black#40,'
#  'STATUS: opponent_moved; FEN: 2r3k1/p3nppp/1p6/6q1/2Qb1N2/6P1/PP3P1P/4R1K1 w - - 0 21'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: c4; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: c4; TARGET: c8; MOVE_NUM: 1; FEN: 2Q3k1/p3nppp/1p6/6q1/3b1N2/6P1/PP3P1P/4R1K1 b - - 0 21; ELO: 1650'
#  'STATUS: opponent_moved; FEN: 2n3k1/p4ppp/1p6/6q1/3b1N2/6P1/PP3P1P/4R1K1 w - - 0 22'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e1; TARGET: e8; MOVE_NUM: 3; FEN: 2n1R1k1/p4ppp/1p6/6q1/3b1N2/6P1/PP3P1P/6K1 b - - 1 22; ELO: 1650'
#  'STATUS: trial_ended; TRIAL: 21'
#  'STATUS: puzzle_loaded; ELO: 1700; PUZZLESTR: CJCzQ,r5r1/pRQ1B3/2n1p3/4p3/3kP3/3q4/P4PPP/5RK1 w - - 3 23,c7c6 g8g2 g1g2 a8g8 e7g5 g8g5 g2h1 d3f1,1705,75,86,452,attraction deflection mate mateIn4 middlegame sacrifice veryLong,https://lichess.org/VhyCzNHD#45,'
#  'STATUS: opponent_moved; FEN: r5r1/pR2B3/2Q1p3/4p3/3kP3/3q4/P4PPP/5RK1 b - - 0 23'
#  'STATUS: correct_move; RESULT: capture; SOURCE: g8; TARGET: g2; MOVE_NUM: 1; FEN: r7/pR2B3/2Q1p3/4p3/3kP3/3q4/P4PrP/5RK1 w - - 0 24; ELO: 1700'
#  'STATUS: opponent_moved; FEN: r7/pR2B3/2Q1p3/4p3/3kP3/3q4/P4PKP/5R2 b - - 0 24'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: a8; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: a8; TARGET: g8; MOVE_NUM: 3; FEN: 6r1/pR2B3/2Q1p3/4p3/3kP3/3q4/P4PKP/5R2 w - - 1 25; ELO: 1700'
#  'STATUS: opponent_moved; FEN: 6r1/pR6/2Q1p3/4p1B1/3kP3/3q4/P4PKP/5R2 b - - 2 25'
#  'STATUS: correct_move; RESULT: capture; SOURCE: g8; TARGET: g5; MOVE_NUM: 5; FEN: 8/pR6/2Q1p3/4p1r1/3kP3/3q4/P4PKP/5R2 w - - 0 26; ELO: 1700'
#  'STATUS: opponent_moved; FEN: 8/pR6/2Q1p3/4p1r1/3kP3/3q4/P4P1P/5R1K b - - 1 26'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: d3; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d3; TARGET: f3; MOVE_NUM: 7; FEN: 8/pR6/2Q1p3/4p1r1/3kP3/5q2/P4P1P/5R1K w - - 2 27; ELO: 1700'
#  'STATUS: trial_ended; TRIAL: 22'
#  'STATUS: puzzle_loaded; ELO: 1750; PUZZLESTR: QRy0P,r4rk1/5p2/2p2Qp1/2qp3p/1p5P/1P2P1P1/2KPNP2/3R3R w - - 4 24,c2b2 a8a2 b2a2 c5c2 f6b2 f8a8,1788,75,96,4159,attraction long mate mateIn3 middlegame sacrifice,https://lichess.org/fgmDe14J#47,'
#  'STATUS: opponent_moved; FEN: r4rk1/5p2/2p2Qp1/2qp3p/1p5P/1P2P1P1/1K1PNP2/3R3R b - - 5 24'
#  'STATUS: correct_move; RESULT: move; SOURCE: a8; TARGET: a2; MOVE_NUM: 1; FEN: 5rk1/5p2/2p2Qp1/2qp3p/1p5P/1P2P1P1/rK1PNP2/3R3R w - - 6 25; ELO: 1750'
#  'STATUS: opponent_moved; FEN: 5rk1/5p2/2p2Qp1/2qp3p/1p5P/1P2P1P1/K2PNP2/3R3R b - - 0 25'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: f8; ORIENTATION: black'
#  'STATUS: illegal_move; RESULT: snapback; SOURCE: f8; TARGET: f8; MOVE_NUM: 3; FEN: 5rk1/5p2/2p2Qp1/2qp3p/1p5P/1P2P1P1/K2PNP2/3R3R b - - 0 25; ELO: 1750'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: f8; TARGET: a8; MOVE_NUM: 3; FEN: r5k1/5p2/2p2Qp1/2qp3p/1p5P/1P2P1P1/K2PNP2/3R3R w - - 1 26; ELO: 1750'
#  'STATUS: trial_ended; TRIAL: 23'
#  'STATUS: puzzle_loaded; ELO: 1700; PUZZLESTR: LkmXx,8/1Q2nk2/8/2Pp1p2/4qP1P/6PK/8/6B1 w - - 3 44,c5c6 e4h1 g1h2 h1f1,1714,79,78,48,endgame fork mate mateIn2 short,https://lichess.org/tqHPAwui#87,'
#  'STATUS: opponent_moved; FEN: 8/1Q2nk2/2P5/3p1p2/4qP1P/6PK/8/6B1 b - - 0 44'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: e4; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: e4; TARGET: h1; MOVE_NUM: 1; FEN: 8/1Q2nk2/2P5/3p1p2/5P1P/6PK/8/6Bq w - - 1 45; ELO: 1700'
#  'STATUS: opponent_moved; FEN: 8/1Q2nk2/2P5/3p1p2/5P1P/6PK/7B/7q b - - 2 45'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: h1; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: h1; TARGET: f1; MOVE_NUM: 3; FEN: 8/1Q2nk2/2P5/3p1p2/5P1P/6PK/7B/5q2 w - - 3 46; ELO: 1700'
#  'STATUS: trial_ended; TRIAL: 24'
#  'STATUS: puzzle_loaded; ELO: 1750; PUZZLESTR: Q1ybg,5rk1/1p5p/1Np1p3/1P3q2/2P5/4P3/1Q2BPPP/R5K1 w - - 3 25,a1a8 f5f2 g1h1 f2e1 e2f1 e1f1,1754,214,37,10,endgame long mate mateIn3,https://lichess.org/LynARjLk#49,'
#  'STATUS: opponent_moved; FEN: R4rk1/1p5p/1Np1p3/1P3q2/2P5/4P3/1Q2BPPP/6K1 b - - 4 25'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: f5; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: f5; TARGET: f2; MOVE_NUM: 1; FEN: R4rk1/1p5p/1Np1p3/1P6/2P5/4P3/1Q2BqPP/6K1 w - - 0 26; ELO: 1750'
#  'STATUS: opponent_moved; FEN: R4rk1/1p5p/1Np1p3/1P6/2P5/4P3/1Q2BqPP/7K b - - 1 26'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: f2; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: f2; TARGET: e1; MOVE_NUM: 3; FEN: R4rk1/1p5p/1Np1p3/1P6/2P5/4P3/1Q2B1PP/4q2K w - - 2 27; ELO: 1750'
#  'STATUS: opponent_moved; FEN: R4rk1/1p5p/1Np1p3/1P6/2P5/4P3/1Q4PP/4qB1K b - - 3 27'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: e1; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e1; TARGET: f1; MOVE_NUM: 5; FEN: R4rk1/1p5p/1Np1p3/1P6/2P5/4P3/1Q4PP/5q1K w - - 0 28; ELO: 1750'
#  'STATUS: trial_ended; TRIAL: 25'
#  'STATUS: puzzle_loaded; ELO: 1800; PUZZLESTR: ct9fT,4nk1r/ppp2pp1/3b3p/3p1Q2/3P4/1NP2PPB/Pq5P/4R1K1 b - - 3 20,b2c3 e1e8 f8e8 f5d7 e8f8 d7d8,1806,77,96,9205,attraction long mate mateIn3 middlegame sacrifice,https://lichess.org/XUCnr8ZH/black#40,'
#  'STATUS: opponent_moved; FEN: 4nk1r/ppp2pp1/3b3p/3p1Q2/3P4/1Nq2PPB/P6P/4R1K1 w - - 0 21'
#  'STATUS: correct_move; RESULT: capture; SOURCE: e1; TARGET: e8; MOVE_NUM: 1; FEN: 4Rk1r/ppp2pp1/3b3p/3p1Q2/3P4/1Nq2PPB/P6P/6K1 b - - 0 21; ELO: 1800'
#  'STATUS: opponent_moved; FEN: 4k2r/ppp2pp1/3b3p/3p1Q2/3P4/1Nq2PPB/P6P/6K1 w - - 0 22'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: f5; TARGET: d7; MOVE_NUM: 3; FEN: 4k2r/pppQ1pp1/3b3p/3p4/3P4/1Nq2PPB/P6P/6K1 b - - 1 22; ELO: 1800'
#  'STATUS: opponent_moved; FEN: 5k1r/pppQ1pp1/3b3p/3p4/3P4/1Nq2PPB/P6P/6K1 w - - 2 23'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: d7; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d7; TARGET: d8; MOVE_NUM: 5; FEN: 3Q1k1r/ppp2pp1/3b3p/3p4/3P4/1Nq2PPB/P6P/6K1 b - - 3 23; ELO: 1800'
#  'STATUS: trial_ended; TRIAL: 26'
#  'STATUS: puzzle_loaded; ELO: 1850; PUZZLESTR: cOzuQ,6k1/R4p1p/4n1p1/3bQ3/6P1/4RPKP/8/3q4 w - - 17 42,e5f6 d1g1 g3h4 g1f2,1891,75,95,5592,endgame fork mate mateIn2 short,https://lichess.org/jcpBfxQj#83,'
#  'STATUS: opponent_moved; FEN: 6k1/R4p1p/4nQp1/3b4/6P1/4RPKP/8/3q4 b - - 18 42'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: d1; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: d1; TARGET: g1; MOVE_NUM: 1; FEN: 6k1/R4p1p/4nQp1/3b4/6P1/4RPKP/8/6q1 w - - 19 43; ELO: 1850'
#  'STATUS: opponent_moved; FEN: 6k1/R4p1p/4nQp1/3b4/6PK/4RP1P/8/6q1 b - - 20 43'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: g1; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g1; TARGET: f2; MOVE_NUM: 3; FEN: 6k1/R4p1p/4nQp1/3b4/6PK/4RP1P/5q2/8 w - - 21 44; ELO: 1850'
#  'STATUS: trial_ended; TRIAL: 27'
#  'STATUS: puzzle_loaded; ELO: 1900; PUZZLESTR: aQzuh,r1bq3r/ppp2pk1/6p1/2bpP3/5P2/2PB4/P3Q1PP/R1B2R1K w - - 3 19,f4f5 h8h2 h1h2 d8h4,1946,74,88,689,attraction kingsideAttack mate mateIn2 middlegame sacrifice short,https://lichess.org/eJWPK9Xj#37,Italian_Game,Italian_Game_Giuoco_Piano'
#  'STATUS: opponent_moved; FEN: r1bq3r/ppp2pk1/6p1/2bpPP2/8/2PB4/P3Q1PP/R1B2R1K b - - 0 19'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: h8; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: h8; TARGET: h2; MOVE_NUM: 1; FEN: r1bq4/ppp2pk1/6p1/2bpPP2/8/2PB4/P3Q1Pr/R1B2R1K w - - 0 20; ELO: 1900'
#  'STATUS: opponent_moved; FEN: r1bq4/ppp2pk1/6p1/2bpPP2/8/2PB4/P3Q1PK/R1B2R2 b - - 0 20'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: d8; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d8; TARGET: h4; MOVE_NUM: 3; FEN: r1b5/ppp2pk1/6p1/2bpPP2/7q/2PB4/P3Q1PK/R1B2R2 w - - 1 21; ELO: 1900'
#  'STATUS: trial_ended; TRIAL: 28'
#  'STATUS: puzzle_loaded; ELO: 1950; PUZZLESTR: jpBoq,1rb2r1k/5pbP/3p4/q1n5/3B2P1/1BP2P2/P2Q4/1K1R2NR b - - 4 22,c5b3 d4g7 h8g7 d2h6 g7h8 h6f8,1966,117,88,19,attraction deflection exposedKing kingsideAttack long mate mateIn3 middlegame,https://lichess.org/ZktlUGVa/black#44,'
#  'STATUS: opponent_moved; FEN: 1rb2r1k/5pbP/3p4/q7/3B2P1/1nP2P2/P2Q4/1K1R2NR w - - 0 23'
#  'STATUS: piece_drag_start; PIECE: wB; SOURCE: d4; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: d4; TARGET: g7; MOVE_NUM: 1; FEN: 1rb2r1k/5pBP/3p4/q7/6P1/1nP2P2/P2Q4/1K1R2NR b - - 0 23; ELO: 1950'
#  'STATUS: opponent_moved; FEN: 1rb2r2/5pkP/3p4/q7/6P1/1nP2P2/P2Q4/1K1R2NR w - - 0 24'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: d2; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: d2; TARGET: g5; MOVE_NUM: 3; FEN: 1rb2r2/5pkP/3p4/q5Q1/6P1/1nP2P2/P7/1K1R2NR b - - 1 24; ELO: 1950'
#  'STATUS: trial_ended; TRIAL: 29'
#  'STATUS: puzzle_loaded; ELO: 1900; PUZZLESTR: iMI4D,3r4/5pkp/2p1bnp1/4P1Q1/p7/2P3NP/1q3PP1/4R1K1 b - - 0 26,f6d5 g3h5 g7h8 g5d8,1942,76,92,2130,mate mateIn2 middlegame pin short,https://lichess.org/O1jNsU1Z/black#52,'
#  'STATUS: opponent_moved; FEN: 3r4/5pkp/2p1b1p1/3nP1Q1/p7/2P3NP/1q3PP1/4R1K1 w - - 1 27'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: g3; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: g3; TARGET: h5; MOVE_NUM: 1; FEN: 3r4/5pkp/2p1b1p1/3nP1QN/p7/2P4P/1q3PP1/4R1K1 b - - 2 27; ELO: 1900'
#  'STATUS: opponent_moved; FEN: 3r3k/5p1p/2p1b1p1/3nP1QN/p7/2P4P/1q3PP1/4R1K1 w - - 3 28'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: g5; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g5; TARGET: d8; MOVE_NUM: 3; FEN: 3Q3k/5p1p/2p1b1p1/3nP2N/p7/2P4P/1q3PP1/4R1K1 b - - 0 28; ELO: 1900'
#  'STATUS: trial_ended; TRIAL: 30'
#  'STATUS: puzzle_loaded; ELO: 1950; PUZZLESTR: xwfDd,3k3r/pp4p1/2b1Qp2/8/1P1p2pq/P2P1Pb1/2P3B1/R3RNK1 w - - 5 27,e6g4 g3f2,1961,81,73,298,mate mateIn1 middlegame oneMove,https://lichess.org/nXhoPj75#53,'
#  'STATUS: opponent_moved; FEN: 3k3r/pp4p1/2b2p2/8/1P1p2Qq/P2P1Pb1/2P3B1/R3RNK1 b - - 0 27'
#  'STATUS: piece_drag_start; PIECE: bB; SOURCE: g3; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g3; TARGET: f2; MOVE_NUM: 1; FEN: 3k3r/pp4p1/2b2p2/8/1P1p2Qq/P2P1P2/2P2bB1/R3RNK1 w - - 1 28; ELO: 1950'
#  'STATUS: trial_ended; TRIAL: 31'
#  'STATUS: puzzle_loaded; ELO: 2000; PUZZLESTR: xrIra,2kn3Q/ppp4p/3r4/4pPNK/4Pq1P/3Pb3/P7/5B1R w - - 1 25,f1h3 d6h6 h5h6 f4h4 h6g7 h4g5 g7f8 e3c5 f8e8 g5h5,2039,77,90,1516,attraction deflection mate mateIn5 middlegame pin sacrifice veryLong,https://lichess.org/37DiAgNL#49,'
#  'STATUS: opponent_moved; FEN: 2kn3Q/ppp4p/3r4/4pPNK/4Pq1P/3Pb2B/P7/7R b - - 2 25'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: d6; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: d6; TARGET: h6; MOVE_NUM: 1; FEN: 2kn3Q/ppp4p/7r/4pPNK/4Pq1P/3Pb2B/P7/7R w - - 3 26; ELO: 2000'
#  'STATUS: opponent_moved; FEN: 2kn3Q/ppp4p/7K/4pPN1/4Pq1P/3Pb2B/P7/7R b - - 0 26'
#  'STATUS: correct_move; RESULT: capture; SOURCE: f4; TARGET: h4; MOVE_NUM: 3; FEN: 2kn3Q/ppp4p/7K/4pPN1/4P2q/3Pb2B/P7/7R w - - 0 27; ELO: 2000'
#  'STATUS: opponent_moved; FEN: 2kn3Q/ppp3Kp/8/4pPN1/4P2q/3Pb2B/P7/7R b - - 1 27'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: h4; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: h4; TARGET: g5; MOVE_NUM: 5; FEN: 2kn3Q/ppp3Kp/8/4pPq1/4P3/3Pb2B/P7/7R w - - 0 28; ELO: 2000'
#  'STATUS: opponent_moved; FEN: 2kn1K1Q/ppp4p/8/4pPq1/4P3/3Pb2B/P7/7R b - - 1 28'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: g5; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: g5; TARGET: h6; MOVE_NUM: 7; FEN: 2kn1K1Q/ppp4p/7q/4pP2/4P3/3Pb2B/P7/7R w - - 2 29; ELO: 2000'
#  'STATUS: trial_ended; TRIAL: 32'
#  'STATUS: puzzle_loaded; ELO: 1950; PUZZLESTR: 4ZGE1,r4r1k/2q2PRp/3p4/2n1p2P/1pB1P3/1P3P2/1P1Q4/1K5R b - - 0 28,h8g7 d2g5 g7h8 g5f6,1984,78,84,79,master mate mateIn2 middlegame short,https://lichess.org/8J0wl7A2/black#56,'
#  'STATUS: opponent_moved; FEN: r4r2/2q2Pkp/3p4/2n1p2P/1pB1P3/1P3P2/1P1Q4/1K5R w - - 0 29'
#  'STATUS: piece_drag_start; PIECE: wP; SOURCE: h5; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: h5; TARGET: h6; MOVE_NUM: 1; FEN: r4r2/2q2Pkp/3p3P/2n1p3/1pB1P3/1P3P2/1P1Q4/1K5R b - - 0 29; ELO: 1950'
#  'STATUS: trial_ended; TRIAL: 33'
#  'STATUS: puzzle_loaded; ELO: 1900; PUZZLESTR: NRaq9,1q4k1/8/1p2p1Kp/1Q1p1pp1/3P4/4P3/3r2P1/2R5 b - - 0 43,b8f8 b5d7 f8f7 d7f7 g8h8 f7e8,1934,221,50,6,endgame exposedKing long mate mateIn3,https://lichess.org/9Xn0A0nm/black#86,'
#  'STATUS: opponent_moved; FEN: 5qk1/8/1p2p1Kp/1Q1p1pp1/3P4/4P3/3r2P1/2R5 w - - 1 44'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: b5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: b5; TARGET: d7; MOVE_NUM: 1; FEN: 5qk1/3Q4/1p2p1Kp/3p1pp1/3P4/4P3/3r2P1/2R5 b - - 2 44; ELO: 1900'
#  'STATUS: opponent_moved; FEN: 6k1/3Q1q2/1p2p1Kp/3p1pp1/3P4/4P3/3r2P1/2R5 w - - 3 45'
#  'STATUS: correct_move; RESULT: capture; SOURCE: d7; TARGET: f7; MOVE_NUM: 3; FEN: 6k1/5Q2/1p2p1Kp/3p1pp1/3P4/4P3/3r2P1/2R5 b - - 0 45; ELO: 1900'
#  'STATUS: opponent_moved; FEN: 7k/5Q2/1p2p1Kp/3p1pp1/3P4/4P3/3r2P1/2R5 w - - 1 46'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f7; TARGET: h7; MOVE_NUM: 5; FEN: 7k/7Q/1p2p1Kp/3p1pp1/3P4/4P3/3r2P1/2R5 b - - 2 46; ELO: 1900'
#  'STATUS: trial_ended; TRIAL: 34'
#  'STATUS: puzzle_loaded; ELO: 1950; PUZZLESTR: HBZTl,1kr5/1p6/4p2p/1p1pP3/3n1P2/1P1N2P1/P1r2K1P/2R2R2 w - - 4 35,f2e3 c2e2 e3d4 e2e4,1957,78,90,976,endgame mate mateIn2 sacrifice short,https://lichess.org/PuOZ7ej8#69,'
#  'STATUS: opponent_moved; FEN: 1kr5/1p6/4p2p/1p1pP3/3n1P2/1P1NK1P1/P1r4P/2R2R2 b - - 5 35'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: c2; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: c2; TARGET: e2; MOVE_NUM: 1; FEN: 1kr5/1p6/4p2p/1p1pP3/3n1P2/1P1NK1P1/P3r2P/2R2R2 w - - 6 36; ELO: 1950'
#  'STATUS: opponent_moved; FEN: 1kr5/1p6/4p2p/1p1pP3/3K1P2/1P1N2P1/P3r2P/2R2R2 b - - 0 36'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: e2; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e2; TARGET: e4; MOVE_NUM: 3; FEN: 1kr5/1p6/4p2p/1p1pP3/3KrP2/1P1N2P1/P6P/2R2R2 w - - 1 37; ELO: 1950'
#  'STATUS: trial_ended; TRIAL: 35'
#  'STATUS: puzzle_loaded; ELO: 2000; PUZZLESTR: M57TS,r2r1bk1/5ppp/2p2pP1/1p6/p2PQ3/P1P2NB1/1P3PP1/qBKbR3 b - - 0 27,d1f3 g6f7 g8f7 e4e6,2024,75,90,888,advancedPawn attraction kingsideAttack mate mateIn2 middlegame short,https://lichess.org/mFAVy7wp/black#54,'
#  'STATUS: opponent_moved; FEN: r2r1bk1/5ppp/2p2pP1/1p6/p2PQ3/P1P2bB1/1P3PP1/qBK1R3 w - - 0 28'
#  'STATUS: piece_drag_start; PIECE: wP; SOURCE: g6; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: g6; TARGET: f7; MOVE_NUM: 1; FEN: r2r1bk1/5Ppp/2p2p2/1p6/p2PQ3/P1P2bB1/1P3PP1/qBK1R3 b - - 0 28; ELO: 2000'
#  'STATUS: opponent_moved; FEN: r2r1b2/5kpp/2p2p2/1p6/p2PQ3/P1P2bB1/1P3PP1/qBK1R3 w - - 0 29'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: e4; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e4; TARGET: e6; MOVE_NUM: 3; FEN: r2r1b2/5kpp/2p1Qp2/1p6/p2P4/P1P2bB1/1P3PP1/qBK1R3 b - - 1 29; ELO: 2000'
#  'STATUS: trial_ended; TRIAL: 36'
#  'STATUS: puzzle_loaded; ELO: 2050; PUZZLESTR: LYGDe,r2q3r/pp2npp1/2np2k1/2p2bN1/2Pp3P/6Q1/PP3PP1/R3R1K1 b - - 4 17,g6f6 g5h7 h8h7 g3g5,2050,76,88,799,clearance mate mateIn2 middlegame sacrifice short,https://lichess.org/uIAKLb5x/black#34,Sicilian_Defense,Sicilian_Defense_Staunton-Cochrane_Variation'
#  'STATUS: opponent_moved; FEN: r2q3r/pp2npp1/2np1k2/2p2bN1/2Pp3P/6Q1/PP3PP1/R3R1K1 w - - 5 18'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: g5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: g5; TARGET: h7; MOVE_NUM: 1; FEN: r2q3r/pp2nppN/2np1k2/2p2b2/2Pp3P/6Q1/PP3PP1/R3R1K1 b - - 6 18; ELO: 2050'
#  'STATUS: opponent_moved; FEN: r2q4/pp2nppr/2np1k2/2p2b2/2Pp3P/6Q1/PP3PP1/R3R1K1 w - - 0 19'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: g3; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g3; TARGET: g5; MOVE_NUM: 3; FEN: r2q4/pp2nppr/2np1k2/2p2bQ1/2Pp3P/8/PP3PP1/R3R1K1 b - - 1 19; ELO: 2050'
#  'STATUS: trial_ended; TRIAL: 37'
#  'STATUS: puzzle_loaded; ELO: 2100; PUZZLESTR: Ixfmc,8/P2R4/8/8/4kpp1/2p5/r4PP1/4K3 w - - 0 47,d7c7 a2a1 e1e2 f4f3 g2f3 g4f3,2129,77,90,855,endgame long mate mateIn3 rookEndgame,https://lichess.org/Gi6R3DrB#93,'
#  'STATUS: opponent_moved; FEN: 8/P1R5/8/8/4kpp1/2p5/r4PP1/4K3 b - - 1 47'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: a2; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: a2; TARGET: a1; MOVE_NUM: 1; FEN: 8/P1R5/8/8/4kpp1/2p5/5PP1/r3K3 w - - 2 48; ELO: 2100'
#  'STATUS: opponent_moved; FEN: 8/P1R5/8/8/4kpp1/2p5/4KPP1/r7 b - - 3 48'
#  'STATUS: piece_drag_start; PIECE: bP; SOURCE: f4; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: f4; TARGET: f3; MOVE_NUM: 3; FEN: 8/P1R5/8/8/4k1p1/2p2p2/4KPP1/r7 w - - 0 49; ELO: 2100'
#  'STATUS: opponent_moved; FEN: 8/P1R5/8/8/4k1p1/2p2P2/4KP2/r7 b - - 0 49'
#  'STATUS: piece_drag_start; PIECE: bP; SOURCE: g4; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g4; TARGET: f3; MOVE_NUM: 5; FEN: 8/P1R5/8/8/4k3/2p2p2/4KP2/r7 w - - 0 50; ELO: 2100'
#  'STATUS: trial_ended; TRIAL: 38'
#  'STATUS: puzzle_loaded; ELO: 2150; PUZZLESTR: I4u0B,r5nr/pp1Q3p/1k1R1p1b/1p2P3/8/2P5/PP3PqP/1K6 b - - 3 24,b6a5 b2b4 a5a4 d6a6 b7a6 d7d1 a4a3 d1b3,2192,77,84,173,clearance mate mateIn4 middlegame sacrifice veryLong,https://lichess.org/kutXHGQI/black#48,'
#  'STATUS: opponent_moved; FEN: r5nr/pp1Q3p/3R1p1b/kp2P3/8/2P5/PP3PqP/1K6 w - - 4 25'
#  'STATUS: piece_drag_start; PIECE: wP; SOURCE: b2; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: b2; TARGET: b4; MOVE_NUM: 1; FEN: r5nr/pp1Q3p/3R1p1b/kp2P3/1P6/2P5/P4PqP/1K6 b - b3 0 25; ELO: 2150'
#  'STATUS: opponent_moved; FEN: r5nr/pp1Q3p/3R1p1b/1p2P3/kP6/2P5/P4PqP/1K6 w - - 1 26'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: d6; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: d6; TARGET: a6; MOVE_NUM: 3; FEN: r5nr/pp1Q3p/R4p1b/1p2P3/kP6/2P5/P4PqP/1K6 b - - 2 26; ELO: 2150'
#  'STATUS: opponent_moved; FEN: r5nr/p2Q3p/p4p1b/1p2P3/kP6/2P5/P4PqP/1K6 w - - 0 27'
#  'STATUS: correct_move; RESULT: move; SOURCE: d7; TARGET: d1; MOVE_NUM: 5; FEN: r5nr/p6p/p4p1b/1p2P3/kP6/2P5/P4PqP/1K1Q4 b - - 1 27; ELO: 2150'
#  'STATUS: opponent_moved; FEN: r5nr/p6p/p4p1b/1p2P3/1P6/k1P5/P4PqP/1K1Q4 w - - 2 28'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: d1; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: d1; TARGET: b3; MOVE_NUM: 7; FEN: r5nr/p6p/p4p1b/1p2P3/1P6/kQP5/P4PqP/1K6 b - - 3 28; ELO: 2150'
#  'STATUS: trial_ended; TRIAL: 39' 'STATUS: block_ended; BLOCK: 0']
# Mismatch in number of start/stop events: 80 vs 31
# 4
# cannot reindex on an axis with duplicate labels
# 5
#           probe-0    probe-1    probe-2    probe-3
# 0       -0.488281  -0.488281          0          0
# 1       -0.488281          0  -0.488281          0
# 2        0.488281   0.976562  -1.953125  -0.976562
# 3       -0.488281  -2.441406   2.929688   1.953125
# 4          7.8125  15.136719 -20.019531  -7.324219
# ...           ...        ...        ...        ...
# 126379 -12.207031 -37.109375 -21.484375  -9.277344
# 126380 -18.554688 -31.738281 -22.460938 -24.902344
# 126381 -30.273438 -32.226562 -23.925781 -30.761719
# 126382 -23.925781 -30.273438 -24.902344 -20.019531
# 126383 -20.019531 -14.648438 -20.019531 -10.742188
#
# [126384 rows x 4 columns]
# Found 59 start/stop events, 59 start/stop eeg events [THESE SHOULD BE THE SAME]
#           probe-0    probe-1    probe-2    probe-3     timestamp value  \
# 0       -0.488281  -0.488281          0          0  1.682108e+12   nan
# 1       -0.488281          0  -0.488281          0  1.682108e+12   nan
# 2        0.488281   0.976562  -1.953125  -0.976562  1.682108e+12   nan
# 3       -0.488281  -2.441406   2.929688   1.953125  1.682108e+12   nan
# 4          7.8125  15.136719 -20.019531  -7.324219  1.682108e+12   nan
# ...           ...        ...        ...        ...           ...   ...
# 126379 -12.207031 -37.109375 -21.484375  -9.277344  1.682109e+12   nan
# 126380 -18.554688 -31.738281 -22.460938 -24.902344  1.682109e+12   nan
# 126381 -30.273438 -32.226562 -23.925781 -30.761719  1.682109e+12   nan
# 126382 -23.925781 -30.273438 -24.902344 -20.019531  1.682109e+12   nan
# 126383 -20.019531 -14.648438 -20.019531 -10.742188  1.682109e+12   nan
#
#              pid
# 0       1bf79614
# 1       1bf79614
# 2       1bf79614
# 3       1bf79614
# 4       1bf79614
# ...          ...
# 126379  1bf79614
# 126380  1bf79614
# 126381  1bf79614
# 126382  1bf79614
# 126383  1bf79614
#
# [126384 rows x 7 columns]
# 6
#           probe-0    probe-1    probe-2    probe-3
# 0       -0.488281          0          0  -0.488281
# 1               0          0  -0.488281          0
# 2        2.929688  -1.464844  -1.464844   2.441406
# 3       -6.835938   1.953125   1.953125  -7.324219
# 4       38.085938 -13.183594 -14.160156  40.039062
# ...           ...        ...        ...        ...
# 142291 -20.507812     -31.25 -17.089844  -7.324219
# 142292  -11.71875 -35.644531 -28.808594  -4.882812
# 142293  -8.300781 -33.691406 -24.902344  -2.929688
# 142294  -8.789062 -30.273438 -16.601562  -4.394531
# 142295  -5.859375 -30.273438 -21.484375  -6.835938
#
# [142296 rows x 4 columns]
# Found 58 start/stop events, 58 start/stop eeg events [THESE SHOULD BE THE SAME]
#           probe-0    probe-1    probe-2    probe-3     timestamp value  \
# 0       -0.488281          0          0  -0.488281  1.682545e+12   nan
# 1               0          0  -0.488281          0  1.682545e+12   nan
# 2        2.929688  -1.464844  -1.464844   2.441406  1.682545e+12   nan
# 3       -6.835938   1.953125   1.953125  -7.324219  1.682545e+12   nan
# 4       38.085938 -13.183594 -14.160156  40.039062  1.682545e+12   nan
# ...           ...        ...        ...        ...           ...   ...
# 142291 -20.507812     -31.25 -17.089844  -7.324219  1.682545e+12   nan
# 142292  -11.71875 -35.644531 -28.808594  -4.882812  1.682545e+12   nan
# 142293  -8.300781 -33.691406 -24.902344  -2.929688  1.682545e+12   nan
# 142294  -8.789062 -30.273438 -16.601562  -4.394531  1.682545e+12   nan
# 142295  -5.859375 -30.273438 -21.484375  -6.835938  1.682545e+12   nan
#
#              pid
# 0       cf88d785
# 1       cf88d785
# 2       cf88d785
# 3       cf88d785
# 4       cf88d785
# ...          ...
# 142291  cf88d785
# 142292  cf88d785
# 142293  cf88d785
# 142294  cf88d785
# 142295  cf88d785
#
# [142296 rows x 7 columns]
# 7
# cannot reindex on an axis with duplicate labels
# 8
#           probe-0    probe-1    probe-2    probe-3
# 0               0          0          0          0
# 1       -0.488281  -0.488281  -0.488281  -0.488281
# 2       -1.953125  -1.953125          0  -1.464844
# 3         3.90625   4.394531  -1.953125   2.929688
# 4      -23.925781 -25.390625   4.882812 -17.578125
# ...           ...        ...        ...        ...
# 143275  -8.300781 -29.296875 -27.832031 -14.648438
# 143276  -1.953125 -20.507812 -28.808594  -4.882812
# 143277   -3.90625 -24.414062 -25.878906          0
# 143278   -3.90625 -29.296875 -32.714844  -8.300781
# 143279  -4.394531 -34.667969 -36.132812  -3.417969
#
# [143280 rows x 4 columns]
# Found 56 start/stop events, 56 start/stop eeg events [THESE SHOULD BE THE SAME]
#           probe-0    probe-1    probe-2    probe-3     timestamp value  \
# 0               0          0          0          0  1.683221e+12   nan
# 1       -0.488281  -0.488281  -0.488281  -0.488281  1.683221e+12   nan
# 2       -1.953125  -1.953125          0  -1.464844  1.683221e+12   nan
# 3         3.90625   4.394531  -1.953125   2.929688  1.683221e+12   nan
# 4      -23.925781 -25.390625   4.882812 -17.578125  1.683221e+12   nan
# ...           ...        ...        ...        ...           ...   ...
# 143275  -8.300781 -29.296875 -27.832031 -14.648438  1.683222e+12   nan
# 143276  -1.953125 -20.507812 -28.808594  -4.882812  1.683222e+12   nan
# 143277   -3.90625 -24.414062 -25.878906          0  1.683222e+12   nan
# 143278   -3.90625 -29.296875 -32.714844  -8.300781  1.683222e+12   nan
# 143279  -4.394531 -34.667969 -36.132812  -3.417969  1.683222e+12   nan
#
#              pid
# 0       168dd1ac
# 1       168dd1ac
# 2       168dd1ac
# 3       168dd1ac
# 4       168dd1ac
# ...          ...
# 143275  168dd1ac
# 143276  168dd1ac
# 143277  168dd1ac
# ...
#  'STATUS: opponent_moved; FEN: 3R4/5kpp/2b5/2b3B1/8/8/PP3rPP/6RK b - - 4 31'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: f2; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: f2; TARGET: f1; MOVE_NUM: 1; FEN: 3R4/5kpp/2b5/2b3B1/8/8/PP4PP/5rRK w - - 5 32; ELO: 1250'
#  'STATUS: trial_ended; TRIAL: 13'
#  'STATUS: puzzle_loaded; ELO: 1200; PUZZLESTR: 5YQsk,r1bR4/p3Rp1k/1p3npp/8/2pN4/8/P1Br1PPP/6K1 b - - 1 25,c8b7 e7f7,1210,80,78,197,mate mateIn1 middlegame oneMove,https://lichess.org/VLq0e2Yl/black#50,'
#  'STATUS: opponent_moved; FEN: r2R4/pb2Rp1k/1p3npp/8/2pN4/8/P1Br1PPP/6K1 w - - 2 26'
#  'STATUS: piece_drag_start; PIECE: wR; SOURCE: e7; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e7; TARGET: f7; MOVE_NUM: 1; FEN: r2R4/pb3R1k/1p3npp/8/2pN4/8/P1Br1PPP/6K1 b - - 0 26; ELO: 1200'
#  'STATUS: trial_ended; TRIAL: 14'
#  'STATUS: puzzle_loaded; ELO: 1250; PUZZLESTR: meW0r,1k1r4/2q2p2/Q1n1p3/2Np4/PP6/5pr1/1P5P/3RR1K1 w - - 0 31,h2g3 c7g3 g1f1 g3g2,1254,167,100,21,mate mateIn2 middlegame short,https://lichess.org/2S5hLcmn#61,'
#  'STATUS: opponent_moved; FEN: 1k1r4/2q2p2/Q1n1p3/2Np4/PP6/5pP1/1P6/3RR1K1 b - - 0 31'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: c7; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: c7; TARGET: g3; MOVE_NUM: 1; FEN: 1k1r4/5p2/Q1n1p3/2Np4/PP6/5pq1/1P6/3RR1K1 w - - 0 32; ELO: 1250'
#  'STATUS: opponent_moved; FEN: 1k1r4/5p2/Q1n1p3/2Np4/PP6/5pq1/1P6/3RRK2 b - - 1 32'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g3; TARGET: g2; MOVE_NUM: 3; FEN: 1k1r4/5p2/Q1n1p3/2Np4/PP6/5p2/1P4q1/3RRK2 w - - 2 33; ELO: 1250'
#  'STATUS: trial_ended; TRIAL: 15'
#  'STATUS: puzzle_loaded; ELO: 1300; PUZZLESTR: f3RtM,r6r/pp3p2/2ppk3/4pNn1/1PP1P3/2P1b3/P7/1K1R1R2 b - - 2 29,e3f4 d1d6,1306,91,65,47,hookMate mate mateIn1 middlegame oneMove,https://lichess.org/Z570wVTc/black#58,'
#  'STATUS: opponent_moved; FEN: r6r/pp3p2/2ppk3/4pNn1/1PP1Pb2/2P5/P7/1K1R1R2 w - - 3 30'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: f5; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: f5; TARGET: g7; MOVE_NUM: 1; FEN: r6r/pp3pN1/2ppk3/4p1n1/1PP1Pb2/2P5/P7/1K1R1R2 b - - 4 30; ELO: 1300'
#  'STATUS: trial_ended; TRIAL: 16'
#  'STATUS: puzzle_loaded; ELO: 1250; PUZZLESTR: P9g3r,1rb2r2/q5Q1/p1n1p1Bp/1pbkN3/2Np1P2/8/PPP3PP/4RRK1 b - - 1 25,a7g7 g6e4,1275,77,95,1162,mate mateIn1 middlegame oneMove,https://lichess.org/vPyXPhu2/black#50,'
#  'STATUS: opponent_moved; FEN: 1rb2r2/6q1/p1n1p1Bp/1pbkN3/2Np1P2/8/PPP3PP/4RRK1 w - - 0 26'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: e5; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: e5; TARGET: c6; MOVE_NUM: 1; FEN: 1rb2r2/6q1/p1N1p1Bp/1pbk4/2Np1P2/8/PPP3PP/4RRK1 b - - 0 26; ELO: 1250'
#  'STATUS: trial_ended; TRIAL: 17'
#  'STATUS: puzzle_loaded; ELO: 1200; PUZZLESTR: O2MNA,r3kbr1/p3qp1p/b1p2p2/3p4/3P2p1/1NN5/PPP2PPP/R2QK2R w KQq - 3 13,e1d2 f8h6 f2f4 h6f4,1240,76,92,1408,mate mateIn2 middlegame short,https://lichess.org/r2neEIGk#25,Queens_Pawn_Game,Queens_Pawn_Game_Steinitz_Countergambit'
#  'STATUS: opponent_moved; FEN: r3kbr1/p3qp1p/b1p2p2/3p4/3P2p1/1NN5/PPPK1PPP/R2Q3R b q - 4 13'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: e7; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: e7; TARGET: e2; MOVE_NUM: 1; FEN: r3kbr1/p4p1p/b1p2p2/3p4/3P2p1/1NN5/PPPKqPPP/R2Q3R w q - 5 14; ELO: 1200'
#  'STATUS: trial_ended; TRIAL: 18'
#  'STATUS: puzzle_loaded; ELO: 1150; PUZZLESTR: oiMAH,2kr1b1r/1bqn2p1/pp2N3/2pppn1p/P6Q/1BNP2B1/1PP2PPP/R3R1K1 b - - 0 17,c7d6 h4d8,1195,75,95,373,mate mateIn1 middlegame oneMove queensideAttack,https://lichess.org/T8sgHSHI/black#34,Sicilian_Defense,Sicilian_Defense_Bowdler_Attack'
#  'STATUS: opponent_moved; FEN: 2kr1b1r/1b1n2p1/pp1qN3/2pppn1p/P6Q/1BNP2B1/1PP2PPP/R3R1K1 w - - 1 18'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h4; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: h4; TARGET: d8; MOVE_NUM: 1; FEN: 2kQ1b1r/1b1n2p1/pp1qN3/2pppn1p/P7/1BNP2B1/1PP2PPP/R3R1K1 b - - 0 18; ELO: 1150'
#  'STATUS: trial_ended; TRIAL: 19'
#  'STATUS: puzzle_loaded; ELO: 1200; PUZZLESTR: pfZXp,1rq4r/p1p1RQpk/2B5/2Bp4/4b1P1/2b5/PPP2P2/3R2K1 w - - 5 25,b2c3 c8g4 g1f1 g4d1,1232,78,88,265,fork mate mateIn2 middlegame short,https://lichess.org/xTmHGan2#49,'
#  'STATUS: opponent_moved; FEN: 1rq4r/p1p1RQpk/2B5/2Bp4/4b1P1/2P5/P1P2P2/3R2K1 b - - 0 25'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: c8; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: c8; TARGET: g4; MOVE_NUM: 1; FEN: 1r5r/p1p1RQpk/2B5/2Bp4/4b1q1/2P5/P1P2P2/3R2K1 w - - 0 26; ELO: 1200'
#  'STATUS: opponent_moved; FEN: 1r5r/p1p1RQpk/2B5/2Bp4/4b1q1/2P5/P1P2P2/3R1K2 b - - 1 26'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: g4; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g4; TARGET: d1; MOVE_NUM: 3; FEN: 1r5r/p1p1RQpk/2B5/2Bp4/4b3/2P5/P1P2P2/3q1K2 w - - 0 27; ELO: 1200'
#  'STATUS: trial_ended; TRIAL: 20'
#  'STATUS: puzzle_loaded; ELO: 1250; PUZZLESTR: 8Ehx9,1rb5/q4pk1/p5pQ/8/6N1/5P1P/6P1/4R2K b - - 8 41,g7g8 g4f6,1254,318,100,11,endgame mate mateIn1 oneMove,https://lichess.org/XB7nPe4M/black#82,'
#  'STATUS: opponent_moved; FEN: 1rb3k1/q4p2/p5pQ/8/6N1/5P1P/6P1/4R2K w - - 9 42'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: g4; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: g4; TARGET: f6; MOVE_NUM: 1; FEN: 1rb3k1/q4p2/p4NpQ/8/8/5P1P/6P1/4R2K b - - 10 42; ELO: 1250'
#  'STATUS: trial_ended; TRIAL: 21'
#  'STATUS: puzzle_loaded; ELO: 1300; PUZZLESTR: 2SCBS,r6r/1b1p1kn1/1p1Pp1p1/2p1P1p1/p1P2pP1/P2B3P/1P2NP1K/2R3R1 w - - 0 31,c1c3 h8h3 h2h3 a8h8,1320,74,86,1077,attraction mate mateIn2 middlegame sacrifice short,https://lichess.org/v9ILkZTF#61,'
#  'STATUS: opponent_moved; FEN: r6r/1b1p1kn1/1p1Pp1p1/2p1P1p1/p1P2pP1/P1RB3P/1P2NP1K/6R1 b - - 1 31'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: h8; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: capture; SOURCE: h8; TARGET: h3; MOVE_NUM: 1; FEN: r7/1b1p1kn1/1p1Pp1p1/2p1P1p1/p1P2pP1/P1RB3r/1P2NP1K/6R1 w - - 0 32; ELO: 1300'
#  'STATUS: opponent_moved; FEN: r7/1b1p1kn1/1p1Pp1p1/2p1P1p1/p1P2pP1/P1RB3K/1P2NP2/6R1 b - - 0 32'
#  'STATUS: piece_drag_start; PIECE: bR; SOURCE: a8; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: a8; TARGET: h8; MOVE_NUM: 3; FEN: 7r/1b1p1kn1/1p1Pp1p1/2p1P1p1/p1P2pP1/P1RB3K/1P2NP2/6R1 w - - 1 33; ELO: 1300'
#  'STATUS: trial_ended; TRIAL: 22'
#  'STATUS: puzzle_loaded; ELO: 1350; PUZZLESTR: jMyvt,4r1k1/pp4p1/2p4p/3Pqb2/2P2b2/3Q3P/PPB2PP1/R5K1 w - - 0 22,d3f5 e5e1 a1e1 e8e1,1400,132,85,10,endgame kingsideAttack mate mateIn2 sacrifice short,https://lichess.org/7irHpHLz#43,'
#  'STATUS: opponent_moved; FEN: 4r1k1/pp4p1/2p4p/3PqQ2/2P2b2/7P/PPB2PP1/R5K1 b - - 0 22'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: e5; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: e5; TARGET: e1; MOVE_NUM: 1; FEN: 4r1k1/pp4p1/2p4p/3P1Q2/2P2b2/7P/PPB2PP1/R3q1K1 w - - 1 23; ELO: 1350'
#  'STATUS: opponent_moved; FEN: 4r1k1/pp4p1/2p4p/3P1Q2/2P2b2/7P/PPB2PP1/4R1K1 b - - 0 23'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e8; TARGET: e1; MOVE_NUM: 3; FEN: 6k1/pp4p1/2p4p/3P1Q2/2P2b2/7P/PPB2PP1/4r1K1 w - - 0 24; ELO: 1350'
#  'STATUS: trial_ended; TRIAL: 23'
#  'STATUS: puzzle_loaded; ELO: 1400; PUZZLESTR: nMRQf,r5rk/5p1p/2np2q1/p1p1pN2/4P3/2PP1Q2/P1B1KPP1/7R b - - 8 25,g6g2 h1h7 h8h7 f3h5,1429,74,97,2226,attraction kingsideAttack mate mateIn2 middlegame sacrifice short,https://lichess.org/swhabUKX/black#50,'
#  'STATUS: opponent_moved; FEN: r5rk/5p1p/2np4/p1p1pN2/4P3/2PP1Q2/P1B1KPq1/7R w - - 0 26'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f3; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: failed; SOURCE: f3; TARGET: g2; MOVE_NUM: 1; FEN: r5rk/5p1p/2np4/p1p1pN2/4P3/2PP4/P1B1KPQ1/7R b - - 0 26; ELO: 1400'
#  'STATUS: trial_ended; TRIAL: 24'
#  'STATUS: puzzle_loaded; ELO: 1350; PUZZLESTR: LESJP,5k2/p4p1p/6q1/3p4/8/2P1r2Q/Pr4PP/4R1K1 w - - 0 27,e1e3 g6b1 e3e1 b1e1,1395,74,91,839,endgame mate mateIn2 short,https://lichess.org/zzqxpjGN#53,'
#  'STATUS: opponent_moved; FEN: 5k2/p4p1p/6q1/3p4/8/2P1R2Q/Pr4PP/6K1 b - - 0 27'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: g6; ORIENTATION: black'
#  'STATUS: correct_move; RESULT: move; SOURCE: g6; TARGET: b1; MOVE_NUM: 1; FEN: 5k2/p4p1p/8/3p4/8/2P1R2Q/Pr4PP/1q4K1 w - - 1 28; ELO: 1350'
#  'STATUS: opponent_moved; FEN: 5k2/p4p1p/8/3p4/8/2P4Q/Pr4PP/1q2R1K1 b - - 2 28'
#  'STATUS: piece_drag_start; PIECE: bQ; SOURCE: b1; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: b1; TARGET: e1; MOVE_NUM: 3; FEN: 5k2/p4p1p/8/3p4/8/2P4Q/Pr4PP/4q1K1 w - - 0 29; ELO: 1350'
#  'STATUS: trial_ended; TRIAL: 25'
#  'STATUS: puzzle_loaded; ELO: 1400; PUZZLESTR: m9gkm,3rr2k/4q1p1/1pp2pQR/p1n2P2/8/7P/PPP2P2/2K3R1 b - - 0 25,g7h6 g6h6 e7h7 h6f6 h7g7 f6g7,1445,75,80,863,deflection endgame exposedKing long mate mateIn3,https://lichess.org/GhSrPOEi/black#50,'
#  'STATUS: opponent_moved; FEN: 3rr2k/4q3/1pp2pQp/p1n2P2/8/7P/PPP2P2/2K3R1 w - - 0 26'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: g6; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: g6; TARGET: h6; MOVE_NUM: 1; FEN: 3rr2k/4q3/1pp2p1Q/p1n2P2/8/7P/PPP2P2/2K3R1 b - - 0 26; ELO: 1400'
#  'STATUS: opponent_moved; FEN: 3rr2k/7q/1pp2p1Q/p1n2P2/8/7P/PPP2P2/2K3R1 w - - 1 27'
#  'STATUS: puzzle_finished; RESULT: timeout'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h6; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: h6; TARGET: g7; MOVE_NUM: 3; FEN: 3rr2k/6Qq/1pp2p2/p1n2P2/8/7P/PPP2P2/2K3R1 b - - 2 27; ELO: 1400'
#  'STATUS: trial_ended; TRIAL: 26'
#  'STATUS: puzzle_loaded; ELO: 1350; PUZZLESTR: iTAIT,2r2r2/1p1qnp1k/p3bQp1/3pPp1p/1P1P3P/P4N2/4BPP1/R4RK1 b - - 3 22,e7g8 f3g5 h7h6 f6h8,1388,76,52,114,mate mateIn2 middlegame short,https://lichess.org/CkKB9usX/black#44,'
#  'STATUS: opponent_moved; FEN: 2r2rn1/1p1q1p1k/p3bQp1/3pPp1p/1P1P3P/P4N2/4BPP1/R4RK1 w - - 4 23'
#  'STATUS: piece_drag_start; PIECE: wN; SOURCE: f3; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: move; SOURCE: f3; TARGET: g5; MOVE_NUM: 1; FEN: 2r2rn1/1p1q1p1k/p3bQp1/3pPpNp/1P1P3P/P7/4BPP1/R4RK1 b - - 5 23; ELO: 1350'
#  'STATUS: opponent_moved; FEN: 2r2rn1/1p1q1p2/p3bQpk/3pPpNp/1P1P3P/P7/4BPP1/R4RK1 w - - 6 24'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f6; ORIENTATION: white'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: f6; TARGET: h8; MOVE_NUM: 3; FEN: 2r2rnQ/1p1q1p2/p3b1pk/3pPpNp/1P1P3P/P7/4BPP1/R4RK1 b - - 7 24; ELO: 1350'
#  'STATUS: trial_ended; TRIAL: 27'
#  'STATUS: puzzle_loaded; ELO: 1400; PUZZLESTR: m5AvO,2rqr3/pb3ppk/1pn1p2B/2ppN2Q/3P4/2P1P2P/PP3PP1/R4RK1 b - - 0 16,g7h6 h5f7 h7h8 e5g6,1406,75,90,5364,fork mate mateIn2 middlegame short,https://lichess.org/4RppLbP4/black#32,Queens_Pawn_Game,Queens_Pawn_Game_London_System'
#  'STATUS: opponent_moved; FEN: 2rqr3/pb3p1k/1pn1p2p/2ppN2Q/3P4/2P1P2P/PP3PP1/R4RK1 w - - 0 17'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: h5; ORIENTATION: white'
#  'STATUS: correct_move; RESULT: capture; SOURCE: h5; TARGET: f7; MOVE_NUM: 1; FEN: 2rqr3/pb3Q1k/1pn1p2p/2ppN3/3P4/2P1P2P/PP3PP1/R4RK1 b - - 0 17; ELO: 1400'
#  'STATUS: opponent_moved; FEN: 2rqr2k/pb3Q2/1pn1p2p/2ppN3/3P4/2P1P2P/PP3PP1/R4RK1 w - - 1 18'
#  'STATUS: piece_drag_start; PIECE: wQ; SOURCE: f7; ORIENTATION: white'
#  'STATUS: illegal_move; RESULT: snapback; SOURCE: f7; TARGET: f7; MOVE_NUM: 3; FEN: 2rqr2k/pb3Q2/1pn1p2p/2ppN3/3P4/2P1P2P/PP3PP1/R4RK1 w - - 1 18; ELO: 1400'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: e5; TARGET: g6; MOVE_NUM: 3; FEN: 2rqr2k/pb3Q2/1pn1p1Np/2pp4/3P4/2P1P2P/PP3PP1/R4RK1 b - - 2 18; ELO: 1400'
#  'STATUS: trial_ended; TRIAL: 28'
#  'STATUS: puzzle_loaded; ELO: 1450; PUZZLESTR: a7mWg,8/8/1pp1k3/p4p2/P1PK1R1p/1P4rP/6P1/8 w - - 3 46,f4h4 c6c5,1495,258,85,18,endgame mate mateIn1 oneMove rookEndgame,https://lichess.org/9YLcIkoj#91,'
#  'STATUS: opponent_moved; FEN: 8/8/1pp1k3/p4p2/P1PK3R/1P4rP/6P1/8 b - - 0 46'
#  'STATUS: piece_drag_start; PIECE: bP; SOURCE: c6; ORIENTATION: black'
#  'STATUS: puzzle_finished; RESULT: solved; SOURCE: c6; TARGET: c5; MOVE_NUM: 1; FEN: 8/8/1p2k3/p1p2p2/P1PK3R/1P4rP/6P1/8 w - - 0 47; ELO: 1450'
#  'STATUS: trial_ended; TRIAL: 29' 'STATUS: block_ended; BLOCK: 0']
# Mismatch in number of start/stop events: 60 vs 39
# 55
#           probe-0     probe-1    probe-2    probe-3
# 0               0           0          0          0
# 1               0           0  -0.488281  -0.488281
# 2       -1.464844   -5.859375  -0.488281  -0.976562
# 3        2.441406    2.441406  -0.976562   1.953125
# 4      -15.136719   -50.78125  -1.464844 -12.207031
# ...           ...         ...        ...        ...
# 101731   -23.4375 -264.648438 -32.226562 -27.832031
# 101732 -28.320312  236.328125 -28.320312 -43.457031
# 101733  -27.34375   22.949219   2.929688 -32.714844
# 101734 -18.554688 -221.191406   6.835938 -24.902344
# 101735 -21.972656   71.289062 -40.527344 -29.785156
#
# [101736 rows x 4 columns]
# Found 59 start/stop events, 59 start/stop eeg events [THESE SHOULD BE THE SAME]
#           probe-0     probe-1    probe-2    probe-3     timestamp value  \
# 0               0           0          0          0  1.682542e+12   nan
# 1               0           0  -0.488281  -0.488281  1.682542e+12   nan
# 2       -1.464844   -5.859375  -0.488281  -0.976562  1.682542e+12   nan
# 3        2.441406    2.441406  -0.976562   1.953125  1.682542e+12   nan
# 4      -15.136719   -50.78125  -1.464844 -12.207031  1.682542e+12   nan
# ...           ...         ...        ...        ...           ...   ...
# 101731   -23.4375 -264.648438 -32.226562 -27.832031  1.682543e+12   nan
# 101732 -28.320312  236.328125 -28.320312 -43.457031  1.682543e+12   nan
# 101733  -27.34375   22.949219   2.929688 -32.714844  1.682543e+12   nan
# 101734 -18.554688 -221.191406   6.835938 -24.902344  1.682543e+12   nan
# 101735 -21.972656   71.289062 -40.527344 -29.785156  1.682543e+12   nan
#
#              pid
# 0       44dd5d31
# 1       44dd5d31
# 2       44dd5d31
# 3       44dd5d31
# 4       44dd5d31
# ...          ...
# 101731  44dd5d31
# 101732  44dd5d31
# 101733  44dd5d31
# 101734  44dd5d31
# 101735  44dd5d31
#
# [101736 rows x 7 columns]
# 56
#           probe-0    probe-1     probe-2    probe-3
# 0               0          0   -0.488281          0
# 1               0          0   -0.488281          0
# 2       -0.976562  -1.953125   20.019531  -1.464844
# 3        1.953125   3.417969  -70.800781   1.953125
# 4      -10.742188 -20.019531  358.398438 -10.742188
# ...           ...        ...         ...        ...
# 111643 -31.738281 -53.710938    -234.375 -33.203125
# 111644 -28.808594   -54.6875 -114.257812 -38.085938
# 111645 -21.972656 -49.804688 -168.945312 -24.414062
# 111646 -25.878906 -43.457031  -72.753906 -13.183594
# 111647  -35.15625 -42.480469  134.765625   -23.4375
#
# [111648 rows x 4 columns]
# Found 60 start/stop events, 60 start/stop eeg events [THESE SHOULD BE THE SAME]
#           probe-0    probe-1     probe-2    probe-3     timestamp value  \
# 0               0          0   -0.488281          0  1.682375e+12   nan
# 1               0          0   -0.488281          0  1.682375e+12   nan
# 2       -0.976562  -1.953125   20.019531  -1.464844  1.682375e+12   nan
# 3        1.953125   3.417969  -70.800781   1.953125  1.682375e+12   nan
# 4      -10.742188 -20.019531  358.398438 -10.742188  1.682375e+12   nan
# ...           ...        ...         ...        ...           ...   ...
# 111643 -31.738281 -53.710938    -234.375 -33.203125  1.682375e+12   nan
# 111644 -28.808594   -54.6875 -114.257812 -38.085938  1.682375e+12   nan
# 111645 -21.972656 -49.804688 -168.945312 -24.414062  1.682375e+12   nan
# 111646 -25.878906 -43.457031  -72.753906 -13.183594  1.682375e+12   nan
# 111647  -35.15625 -42.480469  134.765625   -23.4375  1.682375e+12   nan
#
#              pid
# 0       16230396
# 1       16230396
# 2       16230396
# 3       16230396
# 4       16230396
# ...          ...
# 111643  16230396
# 111644  16230396
# 111645  16230396
# 111646  16230396
# 111647  16230396
#
# [111648 rows x 7 columns]
